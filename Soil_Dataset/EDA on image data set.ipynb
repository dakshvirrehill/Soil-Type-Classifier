# %% [markdown]
# # Performing EDA on Soil Image data set

# %% [markdown]
# ## Types of Soil For Training and Testing
# - Alluvial Soil
# - Black Soil
# - Clay Soil
# - Red Soil

# %% [markdown]
# ## Installing required Libraries

# %%
# !pip install basic-image-eda
# Out:
# Requirement already satisfied: basic-image-eda in c:\users\hp user\anaconda3\lib\site-packages (0.0.3)

# %%
# !pip install git+https://github.com/Soongja/basic-image-eda
# Out:
# Collecting git+https://github.com/Soongja/basic-image-eda
#   Cloning https://github.com/Soongja/basic-image-eda to c:\users\hp user\appdata\local\temp\pip-req-build-h1xqb679
# Requirement already satisfied (use --upgrade to upgrade): basic-image-eda==0.0.3 from git+https://github.com/Soongja/basic-image-eda in c:\users\hp user\anaconda3\lib\site-packages
# Building wheels for collected packages: basic-image-eda
#   Building wheel for basic-image-eda (setup.py): started
#   Building wheel for basic-image-eda (setup.py): finished with status 'done'
#   Created wheel for basic-image-eda: filename=basic_image_eda-0.0.3-py3-none-any.whl size=9754 sha256=b9ab02455e7606a5f9d177db9192cea2ff59c3b07396b98c274acc804df58f67
#   Stored in directory: C:\Users\HP USER\AppData\Local\Temp\pip-ephem-wheel-cache-8fb9c19r\wheels\51\36\98\54af169fbce9223420a419a145e71f551ddfffe2352fa554d5
# Successfully built basic-image-eda
#   Running command git clone -q https://github.com/Soongja/basic-image-eda 'C:\Users\HP USER\AppData\Local\Temp\pip-req-build-h1xqb679'

# %%
from basic_image_eda import BasicImageEDA

# %%
if __name__ == "__main__":
    data_dir = "./Train/Alluvial_Soil/"

    extensions = ['png', 'jpg', 'jpeg']
    threads = 0
    dimension_plot = True
    channel_hist = True
    nonzero = False
    hw_division_factor = 1.0

    BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero, hw_division_factor)
# Out:
#   0%|                                                                                          | 0/175 [00:00<?, ?it/s]
# found 175 images.
# Using 8 threads. (max:8)
# 100%|████████████████████████████████████████████████████████████████████████████████| 175/175 [00:03<00:00, 57.71it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  175
#
# dtype                                    |  uint8
# channels                                 |  [3, 4]
# extensions                               |  ['jpg']
#
# min height                               |  71
# max height                               |  900
# mean height                              |  304.36571428571426
# median height                            |  280
#
# min width                                |  129
# max width                                |  824
# mean width                               |  475.81714285714287
# median width                             |  446
#
# mean height/width ratio                  |  0.6396695008886967
# median height/width ratio                |  0.6278026905829597
# recommended input size(by mean)          |  [304 472] (h x w, multiples of 8)
# recommended input size(by mean)          |  [304 480] (h x w, multiples of 16)
# recommended input size(by mean)          |  [320 480] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.6429256  0.52437204 0.41762325]
# channel std(0~1)                         |  [0.19600394 0.19318552 0.20623934]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 00 minutes 03 seconds

# %%
if __name__ == "__main__": 
    data_dir = "./Train/Black_Soil/"


    extensions = ['png', 'jpg', 'jpeg']
    threads = 0
    dimension_plot = True
    channel_hist = True
    nonzero = False
    hw_division_factor = 1.0

    BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero, hw_division_factor)
# Out:
#   0%|                                                                                          | 0/212 [00:00<?, ?it/s]
# found 212 images.
# Using 8 threads. (max:8)
# 100%|████████████████████████████████████████████████████████████████████████████████| 212/212 [00:02<00:00, 89.54it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  212
#
# dtype                                    |  uint8
# channels                                 |  [3]
# extensions                               |  ['jpg']
#
# min height                               |  45
# max height                               |  314
# mean height                              |  167.04716981132074
# median height                            |  183
#
# min width                                |  69
# max width                                |  410
# mean width                               |  243.94811320754718
# median width                             |  262
#
# mean height/width ratio                  |  0.6847651642593344
# median height/width ratio                |  0.6984732824427481
# recommended input size(by mean)          |  [168 240] (h x w, multiples of 8)
# recommended input size(by mean)          |  [160 240] (h x w, multiples of 16)
# recommended input size(by mean)          |  [160 256] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.25022432 0.22885086 0.2189533 ]
# channel std(0~1)                         |  [0.23348387 0.23369597 0.23225582]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 00 minutes 02 seconds

# %%
if __name__ == "__main__": 
    data_dir = "./Train/Clay_Soil/"


    extensions = ['png', 'jpg', 'jpeg']
    threads = 0
    dimension_plot = True
    channel_hist = True
    nonzero = False
    hw_division_factor = 1.0

    BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero, hw_division_factor)
# Out:
#   0%|                                                                                          | 0/144 [00:00<?, ?it/s]
# found 144 images.
# Using 8 threads. (max:8)
# 100%|████████████████████████████████████████████████████████████████████████████████| 144/144 [00:02<00:00, 60.73it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  144
#
# dtype                                    |  uint8
# channels                                 |  [3, 4]
# extensions                               |  ['jpg']
#
# min height                               |  150
# max height                               |  349
# mean height                              |  217.0625
# median height                            |  192
#
# min width                                |  175
# max width                                |  517
# mean width                               |  277.25
# median width                             |  262
#
# mean height/width ratio                  |  0.7829125338142471
# median height/width ratio                |  0.732824427480916
# recommended input size(by mean)          |  [216 280] (h x w, multiples of 8)
# recommended input size(by mean)          |  [224 272] (h x w, multiples of 16)
# recommended input size(by mean)          |  [224 288] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.59691155 0.5520547  0.50070876]
# channel std(0~1)                         |  [0.23197676 0.22322886 0.21410932]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 00 minutes 02 seconds

# %%
if __name__ == "__main__": 
    data_dir = "./Train/Red_Soil/"


    extensions = ['png', 'jpg', 'jpeg']
    threads = 0
    dimension_plot = True
    channel_hist = True
    nonzero = False
    hw_division_factor = 1.0

    BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero, hw_division_factor)
# Out:
#   0%|                                                                                          | 0/184 [00:00<?, ?it/s]
# found 184 images.
# Using 8 threads. (max:8)
# 100%|████████████████████████████████████████████████████████████████████████████████| 184/184 [00:02<00:00, 80.69it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  184
#
# dtype                                    |  uint8
# channels                                 |  [3]
# extensions                               |  ['jpg']
#
# min height                               |  50
# max height                               |  300
# mean height                              |  155.71195652173913
# median height                            |  166
#
# min width                                |  49
# max width                                |  404
# mean width                               |  238.4673913043478
# median width                             |  259
#
# mean height/width ratio                  |  0.6529695975203975
# median height/width ratio                |  0.640926640926641
# recommended input size(by mean)          |  [152 240] (h x w, multiples of 8)
# recommended input size(by mean)          |  [160 240] (h x w, multiples of 16)
# recommended input size(by mean)          |  [160 224] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.64645326 0.33756757 0.22917949]
# channel std(0~1)                         |  [0.20994553 0.20027025 0.1986827 ]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 00 minutes 02 seconds

# %%
if __name__ == "__main__": 
    data_dir = "./Test/Alluvial_Soil/"

    extensions = ['png', 'jpg', 'jpeg']
    threads = 0
    dimension_plot = True
    channel_hist = True
    nonzero = False
    hw_division_factor = 1.0

    BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero, hw_division_factor)
# Out:
#   0%|                                                                                           | 0/48 [00:00<?, ?it/s]
# found 48 images.
# Using 8 threads. (max:8)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 48/48 [00:02<00:00, 21.29it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  48
#
# dtype                                    |  uint8
# channels                                 |  [3]
# extensions                               |  ['jpg']
#
# min height                               |  128
# max height                               |  800
# mean height                              |  280.8541666666667
# median height                            |  280
#
# min width                                |  146
# max width                                |  942
# mean width                               |  418.2916666666667
# median width                             |  390
#
# mean height/width ratio                  |  0.6714314174718597
# median height/width ratio                |  0.717948717948718
# recommended input size(by mean)          |  [280 416] (h x w, multiples of 8)
# recommended input size(by mean)          |  [288 416] (h x w, multiples of 16)
# recommended input size(by mean)          |  [288 416] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.63000673 0.54611    0.4581029 ]
# channel std(0~1)                         |  [0.21184352 0.20413989 0.22210447]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 00 minutes 02 seconds

# %%
if __name__ == "__main__": 
    data_dir = "./Test/Black_Soil/"

    extensions = ['png', 'jpg', 'jpeg']
    threads = 0
    dimension_plot = True
    channel_hist = True
    nonzero = False
    hw_division_factor = 1.0

    BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero, hw_division_factor)
# Out:
#   0%|                                                                                           | 0/47 [00:00<?, ?it/s]
# found 47 images.
# Using 8 threads. (max:8)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 47/47 [00:02<00:00, 22.44it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  47
#
# dtype                                    |  uint8
# channels                                 |  [3]
# extensions                               |  ['jpg']
#
# min height                               |  134
# max height                               |  275
# mean height                              |  193.53191489361703
# median height                            |  190
#
# min width                                |  183
# max width                                |  377
# mean width                               |  263.1276595744681
# median width                             |  265
#
# mean height/width ratio                  |  0.735505781515323
# median height/width ratio                |  0.7169811320754716
# recommended input size(by mean)          |  [192 264] (h x w, multiples of 8)
# recommended input size(by mean)          |  [192 256] (h x w, multiples of 16)
# recommended input size(by mean)          |  [192 256] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.29431742 0.25857702 0.23877867]
# channel std(0~1)                         |  [0.21413666 0.21486597 0.2135792 ]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 00 minutes 02 seconds

# %%
if __name__ == "__main__": 
    data_dir = "./Test/Clay_Soil/"

    extensions = ['png', 'jpg', 'jpeg']
    threads = 0
    dimension_plot = True
    channel_hist = True
    nonzero = False
    hw_division_factor = 1.0

    BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero, hw_division_factor)
# Out:
#   0%|                                                                                           | 0/47 [00:00<?, ?it/s]
# found 47 images.
# Using 8 threads. (max:8)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 47/47 [00:02<00:00, 22.16it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  47
#
# dtype                                    |  uint8
# channels                                 |  [3]
# extensions                               |  ['jpg']
#
# min height                               |  130
# max height                               |  340
# mean height                              |  221.0212765957447
# median height                            |  192
#
# min width                                |  168
# max width                                |  510
# mean width                               |  290.531914893617
# median width                             |  263
#
# mean height/width ratio                  |  0.7607469791285244
# median height/width ratio                |  0.7300380228136882
# recommended input size(by mean)          |  [224 288] (h x w, multiples of 8)
# recommended input size(by mean)          |  [224 288] (h x w, multiples of 16)
# recommended input size(by mean)          |  [224 288] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.60479474 0.55518615 0.49447936]
# channel std(0~1)                         |  [0.24651815 0.24138243 0.23661418]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 00 minutes 02 seconds

# %%
if __name__ == "__main__":
    data_dir = "./Test/Red_Soil/"

    extensions = ['png', 'jpg', 'jpeg']
    threads = 0
    dimension_plot = True
    channel_hist = True
    nonzero = False
    hw_division_factor = 1.0

    BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero, hw_division_factor)
# Out:
#   0%|                                                                                           | 0/46 [00:00<?, ?it/s]
# found 46 images.
# Using 8 threads. (max:8)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 46/46 [00:02<00:00, 22.29it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  46
#
# dtype                                    |  uint8
# channels                                 |  [3]
# extensions                               |  ['jpg']
#
# min height                               |  57
# max height                               |  340
# mean height                              |  163.34782608695653
# median height                            |  176
#
# min width                                |  82
# max width                                |  368
# mean width                               |  226.8913043478261
# median width                             |  255
#
# mean height/width ratio                  |  0.719938679697231
# median height/width ratio                |  0.6901960784313725
# recommended input size(by mean)          |  [160 224] (h x w, multiples of 8)
# recommended input size(by mean)          |  [160 224] (h x w, multiples of 16)
# recommended input size(by mean)          |  [160 224] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.6364294  0.3110379  0.21837403]
# channel std(0~1)                         |  [0.20586948 0.19777563 0.1987819 ]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 00 minutes 02 seconds
